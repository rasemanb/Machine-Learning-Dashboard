# %%
import pandas as pd 
import json
from sqlalchemy import create_engine
import numpy as np
import datetime as datetime

# %%
csv_file3 = "./Resources/series_data.csv"
df = pd.read_csv(csv_file3)
df
# Out:
#                                             Poster_Link      Series_Title  \
# 0     https://m.media-amazon.com/images/M/MV5BYTRiND...   Game of Thrones
# 1     https://m.media-amazon.com/images/M/MV5BMjhiMz...      Breaking Bad
# 2     https://m.media-amazon.com/images/M/MV5BMTc5Zm...  The Walking Dead
# 3     https://m.media-amazon.com/images/M/MV5BNDVkYj...           Friends
# 4     https://m.media-amazon.com/images/M/MV5BMjEzMD...   Stranger Things
# ...                                                 ...               ...
# 1995  https://m.media-amazon.com/images/M/MV5BYTk4OG...      Shaman Kingu
# 1996  https://m.media-amazon.com/images/M/MV5BMTUyND...    Eerie, Indiana
# 1997  https://m.media-amazon.com/images/M/MV5BMTcxMD...          Gunsmoke
# 1998  https://m.media-amazon.com/images/M/MV5BYWQwNm...         The Cheat
# 1999  https://m.media-amazon.com/images/M/MV5BMjQ5Mj...    Comic Book Men
#
#      Runtime_of_Series Certificate Runtime_of_Episodes  \
# ...

# %%
df.columns
# Out:
# Index(['Poster_Link', 'Series_Title', 'Runtime_of_Series', 'Certificate',
#        'Runtime_of_Episodes', 'Genre', 'IMDB_Rating', 'Overview', 'Star1',
#        'Star2', 'Star3', 'Star4', 'No_of_Votes'],
#       dtype='object')

# %%
clean_df = df[['Series_Title', 'Genre', 'Runtime_of_Series', 'Runtime_of_Episodes', 'IMDB_Rating']]
clean_df
# Out:
#           Series_Title                         Genre Runtime_of_Series  \
# 0      Game of Thrones      Action, Adventure, Drama       (2011–2019)
# 1         Breaking Bad        Crime, Drama, Thriller       (2008–2013)
# 2     The Walking Dead       Drama, Horror, Thriller          (2010– )
# 3              Friends               Comedy, Romance       (1994–2004)
# 4      Stranger Things        Drama, Fantasy, Horror          (2016– )
# ...                ...                           ...               ...
# 1995      Shaman Kingu  Animation, Action, Adventure       (2001–2005)
# 1996    Eerie, Indiana      Adventure, Comedy, Drama       (1991–1992)
# 1997          Gunsmoke                       Western       (1955–1975)
# 1998         The Cheat         Action, Drama, Sci-Fi          (2017– )
# 1999    Comic Book Men            Comedy, Reality-TV       (2012–2018)
#
#      Runtime_of_Episodes  IMDB_Rating
# 0                 57 min          9.3
# ...

# %%
df.replace('..', np.nan, inplace=True)
clean_df = data3_df.dropna(how='any')
clean_df
# Out:
#           Series_Title                         Genre Runtime_of_Series  \
# 0      Game of Thrones      Action, Adventure, Drama       (2011–2019)
# 1         Breaking Bad        Crime, Drama, Thriller       (2008–2013)
# 2     The Walking Dead       Drama, Horror, Thriller          (2010– )
# 3              Friends               Comedy, Romance       (1994–2004)
# 4      Stranger Things        Drama, Fantasy, Horror          (2016– )
# ...                ...                           ...               ...
# 1995      Shaman Kingu  Animation, Action, Adventure       (2001–2005)
# 1996    Eerie, Indiana      Adventure, Comedy, Drama       (1991–1992)
# 1997          Gunsmoke                       Western       (1955–1975)
# 1998         The Cheat         Action, Drama, Sci-Fi          (2017– )
# 1999    Comic Book Men            Comedy, Reality-TV       (2012–2018)
#
#      Runtime_of_Episodes  IMDB_Rating
# 0                 57 min          9.3
# ...

# %%
good_series_df = clean_df.loc[clean_df["IMDB_Rating"] > 7, [
    "Series_Title", "Genre", "Runtime_of_Series", "Runtime_of_Episodes", "IMDB_Rating"]]
good_series_df.head()
# Out:
#        Series_Title                     Genre Runtime_of_Series  \
# 0   Game of Thrones  Action, Adventure, Drama       (2011–2019)
# 1      Breaking Bad    Crime, Drama, Thriller       (2008–2013)
# 2  The Walking Dead   Drama, Horror, Thriller          (2010– )
# 3           Friends           Comedy, Romance       (1994–2004)
# 4   Stranger Things    Drama, Fantasy, Horror          (2016– )
#
#   Runtime_of_Episodes  IMDB_Rating
# 0              57 min          9.3
# 1              49 min          9.5
# 2              44 min          8.2
# 3              22 min          8.9
# 4              51 min          8.7
